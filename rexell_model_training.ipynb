# %% [markdown]
# # Rexell AI - Interactive Model Training (GPU Accelerated)
#
# This notebook provides a modular, step-by-step approach to training the scalping detection models.
#
# ### Why use this notebook?
# - **Modular Execution**: Run specific model categories (e.g., only Boosting) without re-running everything.
# - **GPU Acceleration**: Supports XGBoost, LightGBM, CatBoost, and PyTorch on NVIDIA GPUs.
# - **Interactive Exploration**: View detailed metrics and logs in real-time.

# %%
import os
import sys
import torch

# Ensure the scripts package is importable
if os.getcwd() not in sys.path:
    sys.path.append(os.getcwd())

from scripts.train_all_models import ModelTrainer
import pandas as pd

print("✅ Imports successful")

# Check for GPU acceleration
if torch.cuda.is_available():
    print(f"🚀 GPU detected: {torch.cuda.get_device_name(0)}")
    print("   Boosting and Deep Learning models will automatically use hardware acceleration.")
else:
    print("ℹ️ No GPU detected or CPU-only torch installed. Using CPU for training.")
# Out:
# ✅ Imports successful
# 🚀 GPU detected: NVIDIA GeForce GTX 1650
#    Boosting and Deep Learning models will automatically use hardware acceleration.

# %% [markdown]
# ## 1. Setup & Data Loading
# Initialize the trainer and load the engineered dataset.

# %%
# Initialize trainer
trainer = ModelTrainer(data_path='data/processed/engineered_data.csv')

# Load and split data
trainer.load_and_split_data(test_size=0.2)

print(f"\nTotal features: {trainer.X_train.shape[1]}")
print(f"GPU Mode: {'ENABLED' if trainer.use_gpu else 'DISABLED'}")
# Out:
# 🔍 Checking for GPU acceleration...
#    ✅ PyTorch: GPU detected (NVIDIA GeForce GTX 1650)
# 📊 Loading data...
# ✅ Data loaded: (12000, 19653)
#    Training: (9600, 19653), Testing: (2400, 19653)
#    Target dist (train): {0: np.int64(8604), 1: np.int64(996)}
#
# Total features: 19653
# GPU Mode: ENABLED

# %% [markdown]
# ## 2. Traditional Machine Learning Models
# Trains models like Random Forest and SVM with 5-fold cross-validation. (CPU bound)

# %%
trainer.train_traditional_models()
# Out:
# ...
# 🔵 TRAINING TRADITIONAL ML MODELS
# ...
#
#   [1/10] Training Logistic_Regression...
#      5-fold CV F1 scores: [np.float64(0.5579), np.float64(0.8235), np.float64(0.8356), np.float64(0.8178), np.float64(0.502)]
#
#   ✅ Logistic_Regression
#      Accuracy : 0.9675
#      Precision: 0.8132
#      Recall   : 0.8916
#      F1 Score : 0.8506
#      AUC-ROC  : 0.9919
#      Time     : 7.00s
#      CV F1    : 0.7074 ± 0.1460
#      Confusion Matrix: [[2100, 51], [27, 222]]
#
#   [2/10] Training Random_Forest...
#      5-fold CV F1 scores: [np.float64(0.7302), np.float64(0.6733), np.float64(0.7244), np.float64(0.7284), np.float64(0.6532)]
#
#   ✅ Random_Forest
#      Accuracy : 0.9542
#      Precision: 1.0000
#      Recall   : 0.5582
#      F1 Score : 0.7165
#      AUC-ROC  : 0.9961
#      Time     : 6.17s
#      CV F1    : 0.7019 ± 0.0322
#      Confusion Matrix: [[2151, 0], [110, 139]]
#
#   [3/10] Training Decision_Tree...
# ...

# %% [markdown]
# ## 3. Gradient Boosting Models
# Trains XGBoost, LightGBM, and CatBoost.
# **GPU mode will be used if detected.**

# %%
trainer.train_gradient_boosting_models()
# Out:
# ...
# 🟢 TRAINING GRADIENT BOOSTING MODELS
# ...
#
#   [1/3] Training XGBoost...
#   ❌ XGBoost failed: [21:02:03] C:\actions-runner\_work\xgboost\xgboost\src\context.cc:242: `gpu_id` has been removed since 3.1. Use `device` instead.
#
#   [2/3] Training LightGBM...
# [LightGBM] [Info] Number of positive: 996, number of negative: 8604
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 4795
# [LightGBM] [Info] Number of data points in the train set: 9600, number of used features: 227
# [LightGBM] [Info] Using GPU Device: NVIDIA GeForce GTX 1650, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 35 dense feature groups (0.33 MB) transferred to GPU in 0.001546 secs. 1 sparse feature groups
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# ...

# %% [markdown]
# ## 4. Deep Learning Models
# Trains MLP, TabNet, and a custom PyTorch Neural Network.
# **GPU mode will be used if detected.**

# %%
# Configure deep learning parameters
trainer.train_deep_learning_models(
    epochs=50, 
    batch_size=64, 
    lr=0.001, 
    patience=10
)
# Out:
# ...
# 🟠 TRAINING DEEP LEARNING MODELS
# ...
#
#   [1/3] Training Neural Network (MLP)...
# Iteration 1, loss = 0.16038943
# Validation score: 0.965278
# Iteration 2, loss = 0.01287474
# Validation score: 0.961806
# Iteration 3, loss = 0.00446571
# Validation score: 0.957639
# Iteration 4, loss = 0.00205496
# Validation score: 0.953472
# Iteration 5, loss = 0.00156475
# Validation score: 0.947917
# Iteration 6, loss = 0.00127663
# Validation score: 0.950694
# Iteration 7, loss = 0.00116578
# Validation score: 0.950694
# Iteration 8, loss = 0.00108067
# Validation score: 0.947222
# Iteration 9, loss = 0.00099780
# Validation score: 0.945139
# Iteration 10, loss = 0.00091805
# Validation score: 0.940972
# Iteration 11, loss = 0.00084248
# Validation score: 0.939583
# Iteration 12, loss = 0.00077237
# Validation score: 0.934028
# Validation score did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
#
#      MLP converged after 12 iterations
# ...

# %% [markdown]
# ## 5. Ensemble Models
# Creates Voting and Stacking classifiers using top-performing models.

# %%
trainer.train_ensemble_models()

# %% [markdown]
# ## 6. Analysis & Visualization
# Compare and visualize results.

# %%
trainer.analyze_results()
trainer.create_visualizations(output_dir='results/visualizations')

# %% [markdown]
# ## 7. Save Results
# Persist models and metrics.

# %%
trainer.save_models_and_results(output_dir='models')
print("✅ Everything saved.")
